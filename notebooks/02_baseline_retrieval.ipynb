# %% [markdown]
# # 02 Baseline Retrieval
# Compares BM25 and TF-IDF candidate retrieval.

# %%
from src.preprocessing import load_processed_documents
from src.retrieval import retrieve_candidates
docs = load_processed_documents()
retrieve_candidates(docs, 'Should I pay credit card debt before investing?', 'bm25', 5)[['rank','doc_id','title','retrieval_score']]
