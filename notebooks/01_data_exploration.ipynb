# %% [markdown]
# # 01 Data Exploration
# Loads the processed/sample social finance dataset and inspects fields used for social search.

# %%
from src.data_collection import build_or_load_documents
docs = build_or_load_documents(use_sample=True)
docs.head()
