# %% [markdown]
# # 04 Evaluation
# Runs social usefulness metrics and ablation study.

# %%
from src.evaluation import run_evaluation
metrics, ablation = run_evaluation()
display(metrics)
display(ablation)
